# %% [markdown]
# <a href="https://colab.research.google.com/github/rcgopi100/CNNPretrainedInceptionV3/blob/main/Inception_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Numpy, Keras Image and InceptionV3 libraries
import numpy as np
from keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications import inception_v3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7fc7f0de-35db-4c18-b98f-cd5cafdc72f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fc7f0de-35db-4c18-b98f-cd5cafdc72f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving boat.jpg to boat.jpg

# %%
model = InceptionV3(weights='imagenet')
model

# %%
img = image.load_img('boat.jpg', target_size=(299,299))
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F8817C64150>

# %%
#convert image to array
input_img = image.img_to_array(img)
input_img = np.expand_dims(input_img, axis=0)
input_img = inception_v3.preprocess_input(input_img)
input_img
# Out:
# array([[[[ 0.79607844,  0.81960785,  0.67058825],
#          [ 0.79607844,  0.81960785,  0.67058825],
#          [ 0.7882353 ,  0.8117647 ,  0.6627451 ],
#          ...,
#          [ 0.7490196 ,  0.78039217,  0.6627451 ],
#          [ 0.7490196 ,  0.78039217,  0.6627451 ],
#          [ 0.7490196 ,  0.78039217,  0.6627451 ]],
#
#         [[ 0.79607844,  0.81960785,  0.67058825],
#          [ 0.79607844,  0.81960785,  0.67058825],
#          [ 0.7882353 ,  0.8117647 ,  0.6627451 ],
#          ...,
#          [ 0.7490196 ,  0.78039217,  0.6627451 ],
#          [ 0.7490196 ,  0.78039217,  0.6627451 ],
#          [ 0.7490196 ,  0.78039217,  0.6627451 ]],
#
#         [[ 0.79607844,  0.81960785,  0.67058825],
#          [ 0.79607844,  0.81960785,  0.67058825],
#          [ 0.7882353 ,  0.8117647 ,  0.6627451 ],
#          ...,
#          [ 0.7490196 ,  0.78039217,  0.6627451 ],
#          [ 0.7490196 ,  0.78039217,  0.6627451 ],
#          [ 0.7490196 ,  0.78039217,  0.6627451 ]],
#
# ...

# %%
predict_img = model.predict(input_img)
predict_img
# Out:
# array([[7.93242871e-05, 1.58672789e-04, 1.65201258e-04, 6.17119804e-05,
#         1.50497523e-04, 8.15498279e-05, 7.70324259e-05, 5.63759750e-05,
#         9.00740342e-05, 4.85937053e-05, 1.63986173e-04, 1.79541938e-04,
#         2.05844190e-04, 4.05590690e-05, 2.89637130e-04, 9.84248254e-05,
#         1.21721714e-04, 8.76354970e-05, 6.85585692e-05, 5.15232605e-05,
#         6.00928943e-05, 7.81590061e-05, 5.47572745e-05, 1.11831680e-04,
#         4.28025705e-05, 1.08352535e-04, 2.05621080e-04, 1.94192224e-04,
#         1.17842807e-04, 8.75356782e-05, 2.43818780e-04, 3.04753426e-04,
#         2.97659048e-04, 3.46931702e-05, 3.58913203e-05, 8.83304092e-05,
#         1.57254690e-04, 1.12707057e-04, 2.34034102e-04, 2.27103548e-04,
#         1.28687519e-04, 2.07778299e-04, 8.99510196e-05, 8.63383248e-05,
#         1.22158395e-04, 9.54222778e-05, 1.29687818e-04, 2.28606179e-04,
#         1.09342414e-04, 1.00372592e-04, 2.55030056e-04, 4.73609143e-05,
# ...

# %%
top_five_predict = inception_v3.decode_predictions(predict_img, top=5)
top_five_predict
# Out:
# [[('n03216828', 'dock', 0.36978266),
#   ('n02859443', 'boathouse', 0.25278783),
#   ('n03933933', 'pier', 0.06304911),
#   ('n09332890', 'lakeside', 0.036876522),
#   ('n03877845', 'palace', 0.01331465)]]
